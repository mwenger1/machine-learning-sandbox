# %%
import pandas as pd
file_path = './data/brain-tumor-trials.csv'
trial_data = pd.read_csv(file_path)

# %%
trial_data.head()
# Out:
#    Rank   NCT Number                                              Title  \
# 0     1  NCT03286335  Local Control, Quality of Life and Toxicities ...
# 1     2  NCT02740933  Demeclocycline Fluorescence for Intraoperative...
# 2     3  NCT03328858  Ketogenic Diet in Children With Malignant or R...
# 3     4  NCT02367469        Tryptophan Metabolism in Human Brain Tumors
# 4     5  NCT02956291  Multi-Parametric Quantitative MR Imaging in Ev...
#
#   Acronym              Status         Study Results    Conditions  \
# 0     NaN          Recruiting  No Results Available   Brain Tumor
# 1     NaN  Not yet recruiting  No Results Available   Brain Tumor
# 2     NaN          Recruiting  No Results Available  Brain Tumors
# 3     NaN          Recruiting  No Results Available  Brain Tumors
# 4     NaN          Recruiting  No Results Available   Brain Tumor
#
#                                Interventions  \
# 0                Radiation: Proton Radiation
# ...

# %%
trial_data.Rank.count()
# Out:
# 455

# %%
trial_data
# Out:
#      Rank   NCT Number                                              Title  \
# 0       1  NCT03286335  Local Control, Quality of Life and Toxicities ...
# 1       2  NCT02740933  Demeclocycline Fluorescence for Intraoperative...
# 2       3  NCT03328858  Ketogenic Diet in Children With Malignant or R...
# 3       4  NCT02367469        Tryptophan Metabolism in Human Brain Tumors
# 4       5  NCT02956291  Multi-Parametric Quantitative MR Imaging in Ev...
# 5       6  NCT02824731  Comparison of Proton and Photon Radiotherapy o...
# 6       7  NCT02947373  Pilot Study of Safety and Toxicity of Acquirin...
# 7       8  NCT02428972  Assessment of Cognitive Functions and Quality ...
# 8       9  NCT02914067  Cognitive Biomarkers in Pediatric Brain Tumor ...
# 9      10  NCT02191488  ALA-induced PpIX Fluorescence During Brain Tum...
# 10     11  NCT02754544  Using Electrocorticogram (ECoG) in Predicting ...
# 11     12  NCT03394716  Monitoring MRI Changes Before and During Radio...
# ...
